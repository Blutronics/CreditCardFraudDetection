# %% [markdown]
# <a href="https://colab.research.google.com/github/Blutronics/CreditCardFraudDetection/blob/main/creditCardFraudDection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
credDf = pd.read_csv("CSV//credit_card.csv")
credDf.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
credDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
credDf.Class.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
import seaborn as sns

# %%
credDf.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
from imblearn.over_sampling import BorderlineSMOTE

# %%
from sklearn.datasets import make_classification

# %%
credDfx = credDf.copy()

# %%
credDfx.drop(columns='Class',inplace=True)
credDfx.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3  0.647376 -0.221929  0.062723  0.061458  123.50
# 4 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 30 columns]

# %%
credDf.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
blsm = BorderlineSMOTE(random_state=42)
datars, targetrs = blsm.fit_resample(credDfx, credDf.Class)

# %%
from collections import Counter
from numpy import where
import matplotlib.pyplot as plt

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=42)
datarsmote, targetrsmote = sm.fit_resample(credDfx, credDf.Class)

# %%
tempXX=datarsmote.to_numpy()
tempYY=targetrsmote.to_numpy()

counter = Counter(tempYY)
for label, _ in counter.items():
	row_ix = where(tempYY == label)[0]
	plt.scatter(tempXX[row_ix, 0], tempXX[row_ix, 1], label=str(label))
plt.legend()
plt.show()

# %%
tempX=credDfx.to_numpy()
tempY=credDf.Class.to_numpy()

counter = Counter(tempY)
for label, _ in counter.items():
	row_ix = where(tempY == label)[0]
	plt.scatter(tempX[row_ix, 0], tempX[row_ix, 1], label=str(label))
plt.legend()
plt.show()

# %%
newDatars=datars.to_numpy()
newTargetrs=targetrs.to_numpy()

counter = Counter(newTargetrs)
for label, _ in counter.items():
	row_ix = where(newTargetrs == label)[0]
	plt.scatter(newDatars[row_ix, 0], newDatars[row_ix, 1], label=str(label))
plt.legend()
plt.show()

# %%
borderLineSmoteDf = pd.concat([datars, targetrs], axis=1)

# %%
borderLineSmoteDf.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
undersampleMajor = RandomUnderSampler(sampling_strategy='majority')

# %%
undersamplePercent = RandomUnderSampler(sampling_strategy=0.5)

# %%
xUnderPer, yUnderPer = undersamplePercent.fit_resample(credDfx, credDf.Class)

# %%
xUnder, yUnder = undersampleMajor.fit_resample(credDfx, credDf.Class)

# %%
print(type(xUnder))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
counter = Counter(tempY)
for label, _ in counter.items():
	row_ix = where(tempY == label)[0]
	plt.scatter(tempX[row_ix, 0], tempX[row_ix, 1], label=str(label))
plt.legend()
plt.show()

# %%
print(type(xUnderPer))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tempXunderMajorPer=xUnderPer.to_numpy()
tempYunderMajorPer=yUnderPer.to_numpy()

counter = Counter(tempYunderMajorPer)
for label, _ in counter.items():
	row_ix = where(tempYunderMajorPer == label)[0]
	plt.scatter(tempXunderMajorPer[row_ix, 0], tempXunderMajorPer[row_ix, 1], label=str(label))
plt.legend()
plt.show()

# %%
tempXunderMajor=xUnder.to_numpy()
tempYunderMajor=yUnder.to_numpy()

counter = Counter(tempYunderMajor)
for label, _ in counter.items():
	row_ix = where(tempYunderMajor == label)[0]
	plt.scatter(tempXunderMajor[row_ix, 0], tempXunderMajor[row_ix, 1], label=str(label))
plt.legend()
plt.show()

# %%
underSampledDf = pd.concat([xUnderPer, yUnderPer], axis=1)

# %%
print(type(underSampledDf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
underSampledDfNorm = scale(underSampledDf)

# %%
borderLineSmoteDfNorm = scale(borderLineSmoteDf)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(borderLineSmoteDf.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(underSampledDf.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
pcaBorder = PCA(n_components = 31)
# pcaUnder = PCA(n_components = 31)

# %%
pcaValsBorder = pcaBorder.fit_transform(borderLineSmoteDfNorm)
# pcaValsUnder = pcaUnder.fit_transform(underSampledDfNorm)

# %%
varBorder = pcaBorder.explained_variance_ratio_
varBorder
# Out:
# array([4.12086638e-01, 1.21445153e-01, 9.29682324e-02, 7.30577219e-02,
#        5.32269330e-02, 3.60752408e-02, 2.93107886e-02, 2.82977784e-02,
#        2.37773655e-02, 2.31045240e-02, 2.18600042e-02, 1.52821312e-02,
#        1.41180193e-02, 1.04637355e-02, 8.39698065e-03, 6.39947368e-03,
#        5.31125796e-03, 4.91109886e-03, 3.54297430e-03, 3.11901011e-03,
#        3.02124476e-03, 1.85168792e-03, 1.71098082e-03, 1.38160930e-03,
#        1.13467569e-03, 1.10791682e-03, 9.23784472e-04, 8.66824701e-04,
#        6.75193405e-04, 4.35858134e-04, 1.35162203e-04])

# %%
# varUnder = pcaUnder.explained_variance_ratio_
# varUnder
# Out:
# array([3.73741299e-01, 9.05091026e-02, 6.14865103e-02, 5.07853880e-02,
#        4.78111222e-02, 4.68250765e-02, 3.60999964e-02, 3.46684328e-02,
#        3.12105283e-02, 2.82647888e-02, 2.74831366e-02, 2.42632373e-02,
#        2.26960178e-02, 1.75347795e-02, 1.59596572e-02, 1.55241834e-02,
#        1.26088008e-02, 1.05542876e-02, 8.66390494e-03, 7.99147381e-03,
#        6.87130698e-03, 6.21406845e-03, 4.90683189e-03, 3.49122454e-03,
#        3.38843327e-03, 2.48624572e-03, 2.30932820e-03, 2.11458862e-03,
#        1.92468108e-03, 1.25554073e-03, 3.56027171e-04])

# %%
xBorder = pd.DataFrame(pcaBorder.components_)
xBorder.head(16)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.106913  0.224708 -0.230336  0.248827 -0.253217  0.236231  0.171576
# 1  -0.079091 -0.029860  0.110794  0.001850 -0.000540  0.026760  0.193162
# 2  -0.202730  0.104996 -0.135693  0.069091 -0.015186  0.054927 -0.276956
# 3   0.164309  0.306741 -0.256654  0.247263  0.070013  0.255466  0.088045
# 4   0.002155 -0.158676  0.021873 -0.034582 -0.177532 -0.204664  0.076286
# 5   0.107644 -0.070113 -0.081446 -0.054184 -0.002803 -0.082155  0.136821
# 6  -0.092639 -0.029226 -0.017061 -0.021753  0.055130  0.004248  0.014424
# 7  -0.551023 -0.034989  0.027521  0.051347 -0.013399 -0.040259  0.264296
# 8  -0.589611  0.074330 -0.068471  0.084662  0.089273  0.113202 -0.041014
# 9  -0.086627 -0.016630 -0.013686  0.005752 -0.003158 -0.017678  0.067851
# 10 -0.259290  0.138156 -0.065318  0.143114 -0.004280  0.082737  0.158490
# 11  0.231049  0.102363 -0.119146 -0.007112  0.115070  0.072799 -0.104128
# 12 -0.204907  0.087234 -0.198342  0.122870 -0.143458 -0.029481 -0.016905
# 2   0.089819 -0.025899 -0.033489  0.256897  0.068563  0.092404
# 3   0.153948 -0.231400 -0.089696 -0.145408  0.204674 -0.210762
# 4  -0.043121  0.179219  0.181585  0.018262  0.619314  0.058833
# 5   0.583189  0.071467  0.150692  0.096761  0.109298 -0.007253
# 6  -0.019579  0.150470  0.065553 -0.392898  0.246288  0.022062
# 7  -0.035981 -0.615865  0.036564  0.283899  0.286661  0.126829
# 8  -0.110595 -0.277669  0.036710 -0.483578  0.283013  0.140262
# 9  -0.083186 -0.185815  0.130752  0.040726 -0.090441 -0.160949
# 10 -0.310886 -0.365296  0.061850  0.256417 -0.018199  0.021908
# 11 -0.366738  0.450437  0.216236  0.201249  0.184526 -0.108709
# 12 -0.262948  0.065577 -0.174615  0.048776  0.087537  0.239750
# 13  0.151396  0.151230 -0.705665  0.317677  0.226931  0.122100
# 14  0.477771 -0.071329  0.112776 -0.074583 -0.025118  0.218047
# 15 -0.009216  0.051875 -0.278507 -0.160131 -0.032603  0.142451
#
# [16 rows x 31 columns]

# %%
var1Border = np.cumsum(np.round(varBorder, decimals = 4) * 100)
var1Border
# Out:
# array([ 41.21,  53.35,  62.65,  69.96,  75.28,  78.89,  81.82,  84.65,
#         87.03,  89.34,  91.53,  93.06,  94.47,  95.52,  96.36,  97.  ,
#         97.53,  98.02,  98.37,  98.68,  98.98,  99.17,  99.34,  99.48,
#         99.59,  99.7 ,  99.79,  99.88,  99.95,  99.99, 100.  ])

# %%
# var1Under = np.cumsum(np.round(varUnder, decimals = 4) * 100)
# var1Under
# Out:
# array([ 37.37,  46.42,  52.57,  57.65,  62.43,  67.11,  70.72,  74.19,
#         77.31,  80.14,  82.89,  85.32,  87.59,  89.34,  90.94,  92.49,
#         93.75,  94.81,  95.68,  96.48,  97.17,  97.79,  98.28,  98.63,
#         98.97,  99.22,  99.45,  99.66,  99.85,  99.98, 100.02])

# %%
plt.plot(var1Border, color = "red")

# %%
# plt.plot(var1Under, color = "red")

# %%
pca_dataBorder = pd.DataFrame(pcaValsBorder)

# %%
# pca_dataUnder = pd.DataFrame(pcaValsUnder)

# %%
compCol = []
for i in range(31):
    compCol.append('Comp'+str(i))

# %%
pca_dataBorder.columns = compCol
# pca_dataUnder.columns = compCol

# %%
pca_dataBorder.head()
# Out:
#       Comp0     Comp1     Comp2     Comp3     Comp4     Comp5     Comp6  \
# 0  2.773253 -0.147786  0.575963 -0.283091  0.922948  0.326522 -1.033913
# 1  2.683190  0.106814  0.774734 -0.334246  0.222502 -0.657931  0.322854
# 2  3.008108 -0.126941  0.439576 -0.167748  0.395802  1.202023  0.208197
# 3  3.122331  0.194299  0.253071 -1.218522 -0.888375 -0.122475  1.550732
# 4  2.634598 -0.532173  1.098186  0.155040  0.609181 -0.346459  0.178886
#
#       Comp7     Comp8     Comp9  ...    Comp21    Comp22    Comp23    Comp24  \
# 0  1.470521  1.717303 -0.671743  ... -0.118678 -0.160184 -0.245839 -0.040540
# 1  1.770092  0.800634 -0.252178  ...  0.160613  0.240996  0.165761  0.233917
# 2  3.075022  1.213932 -1.455123  ... -0.522123  0.099357 -0.199701 -0.261380
# 3  1.597918  0.530881 -0.789748  ... -0.311459 -0.305508 -0.375203 -0.278041
# 4  1.867269  0.090447  0.698336  ... -0.292389 -0.231953 -0.403428  0.273963
#
#      Comp25    Comp26    Comp27    Comp28    Comp29    Comp30
# 0  0.057155  0.055956 -0.053144 -0.067122 -0.069331  0.013650
# 1 -0.071009 -0.024694 -0.060073  0.083417  0.149333 -0.001736
# 2 -0.241424  0.185142 -0.274133  0.478619 -0.302504  0.039286
# 3 -0.310586  0.478461 -0.222256  0.074117  0.145138  0.005119
# 4  0.158477  0.105406 -0.013554  0.123234  0.112259  0.041845
#
# [5 rows x 31 columns]

# %%
finalBorder = pd.concat([targetrsmote, pca_dataBorder.iloc[:, 0:7]], axis = 1)
# finalUnder = pd.concat([yUnderPer, pca_dataUnder.iloc[:, 0:9]], axis = 1)

# %%
finalBorder.head()
# Out:
#    Class     Comp0     Comp1     Comp2     Comp3     Comp4     Comp5     Comp6
# 0      0  2.773253 -0.147786  0.575963 -0.283091  0.922948  0.326522 -1.033913
# 1      0  2.683190  0.106814  0.774734 -0.334246  0.222502 -0.657931  0.322854
# 2      0  3.008108 -0.126941  0.439576 -0.167748  0.395802  1.202023  0.208197
# 3      0  3.122331  0.194299  0.253071 -1.218522 -0.888375 -0.122475  1.550732
# 4      0  2.634598 -0.532173  1.098186  0.155040  0.609181 -0.346459  0.178886

# %%
# finalUnder.head()

# %%
import statsmodels.formula.api as smodel

# %%
finalBorder.head()
# Out:
#    Class     Comp0     Comp1     Comp2     Comp3     Comp4     Comp5  \
# 0      0  2.773253 -0.147786  0.575963 -0.283091  0.922948  0.326522
# 1      0  2.683190  0.106814  0.774734 -0.334246  0.222502 -0.657931
# 2      0  3.008108 -0.126941  0.439576 -0.167748  0.395802  1.202023
# 3      0  3.122331  0.194299  0.253071 -1.218522 -0.888375 -0.122475
# 4      0  2.634598 -0.532173  1.098186  0.155040  0.609181 -0.346459
#
#       Comp6  pred
# 0 -1.033913   0.0
# 1  0.322854   0.0
# 2  0.208197   0.0
# 3  1.550732   0.0
# 4  0.178886   0.0

# %%
border_model = smodel.logit('Class ~ Comp0 + Comp1 + Comp2 + Comp3 + Comp4 + Comp5 + Comp6', data = finalBorder).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.010530
#          Iterations 15

# %%
border_model.summary2() # for AIC
border_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:               568630
# Model:                          Logit   Df Residuals:                   568622
# Method:                           MLE   Df Model:                            7
# Date:                Wed, 17 Aug 2022   Pseudo R-squ.:                  0.9848
# Time:                        18:46:14   Log-Likelihood:                -5987.5
# converged:                       True   LL-Null:                   -3.9414e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.8891      0.280     85.178      0.000      23.339      24.439
# Comp0        -10.5191      0.109    -96.487      0.000     -10.733     -10.305
# Comp1          1.5751      0.045     34.753      0.000       1.486       1.664
# Comp2         -0.6103      0.040    -15.278      0.000      -0.689      -0.532
# Comp3          0.1840      0.042      4.372      0.000       0.101       0.266
# Comp4         -2.7565      0.040    -68.195      0.000      -2.836      -2.677
# Comp5          0.0981      0.016      5.994      0.000       0.066       0.130
# Comp6          0.4847      0.026     18.434      0.000       0.433       0.536
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.71 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
border_pred = border_model.predict(finalBorder.iloc[ :, 0: ])

# %%
from sklearn.metrics import roc_curve, auc

# %%
fprB, tprB, thresholdsB = roc_curve(finalBorder.Class, border_pred)

# %%
optimal_idxB = np.argmax(tprB - fprB)

# %%
optimal_thresholdB = thresholdsB[optimal_idxB]
optimal_thresholdB
# Out:
# 0.31433001109142034

# %%
roc_aucB = auc(fprB, tprB)
print("Area under the ROC curve : %f" % roc_aucB)
# Out:
# Area under the ROC curve : 0.999894

# %%
finalBorder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Class   568630 non-null  int64
#  1   Comp0   568630 non-null  float64
#  2   Comp1   568630 non-null  float64
#  3   Comp2   568630 non-null  float64
#  4   Comp3   568630 non-null  float64
#  5   Comp4   568630 non-null  float64
#  6   Comp5   568630 non-null  float64
#  7   Comp6   568630 non-null  float64
# dtypes: float64(7), int64(1)
# memory usage: 34.7 MB

# %%
finalBorder["pred"] = np.zeros(568630)

# %%
finalBorder.loc[border_pred  > optimal_thresholdB, "pred"] = 1

# %%
finalBorder['pred'].value_counts()
# Out:
# 1.0    284589
# 0.0    284041
# Name: pred, dtype: int64

# %%
from sklearn.metrics import classification_report

# %%
classificationB = classification_report(finalBorder["pred"], finalBorder["Class"])
print(classificationB)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    284041
#          1.0       1.00      1.00      1.00    284589
#
#     accuracy                           1.00    568630
#    macro avg       1.00      1.00      1.00    568630
# weighted avg       1.00      1.00      1.00    568630

# %%
from sklearn.model_selection import train_test_split

# %%
train_dataB, test_dataB = train_test_split(finalBorder, test_size = 0.3) # 30% test data

# %%
borderTrain_model = smodel.logit('Class ~ Comp0 + Comp1 + Comp2 + Comp3 + Comp4 + Comp5 + Comp6', data = train_dataB).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.011443
#          Iterations 15

# %%
test_predB = border_model.predict(test_dataB)

# %%
test_dataB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170589 entries, 507812 to 169633
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Class   170589 non-null  int64
#  1   Comp0   170589 non-null  float64
#  2   Comp1   170589 non-null  float64
#  3   Comp2   170589 non-null  float64
#  4   Comp3   170589 non-null  float64
#  5   Comp4   170589 non-null  float64
#  6   Comp5   170589 non-null  float64
#  7   Comp6   170589 non-null  float64
#  8   pred    170589 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 13.0 MB

# %%
test_dataB["test_pred"] = np.zeros(170589)

# %%
test_dataB.loc[test_predB > optimal_thresholdB, "test_pred"] = 1

# %%
confusion_matrixB = pd.crosstab(test_dataB.test_pred, test_dataB['Class'])
confusion_matrixB
# Out:
# Class          0      1
# test_pred
# 0.0        85234     84
# 1.0          166  85105

# %%
accuracy_testB = (85234+85105)/(85234+85105+84+166)
accuracy_testB
# Out:
# 0.9985344893281513

# %%
classification_testB = classification_report(test_dataB["test_pred"], test_dataB["Class"])
print(classification_testB)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     85318
#          1.0       1.00      1.00      1.00     85271
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589

# %%
from sklearn import metrics

# %%
fprBtest, tprBtest, thresholdBtest = metrics.roc_curve(test_dataB["Class"], test_predB)

# %%
plt.plot(fprBtest, tprBtest);plt.xlabel("False positive rate");plt.ylabel("True positive rate")
# Out:
# Text(0, 0.5, 'True positive rate')

# %%
roc_auc_test = metrics.auc(fprBtest, tprBtest)
roc_auc_test
# Out:
# 0.9999299214230994

# %%
train_dataB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398041 entries, 542581 to 148454
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Class   398041 non-null  int64
#  1   Comp0   398041 non-null  float64
#  2   Comp1   398041 non-null  float64
#  3   Comp2   398041 non-null  float64
#  4   Comp3   398041 non-null  float64
#  5   Comp4   398041 non-null  float64
#  6   Comp5   398041 non-null  float64
#  7   Comp6   398041 non-null  float64
#  8   pred    398041 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 30.4 MB

# %%
train_dataB["train_pred"] = np.zeros(398041)

# %%
train_predB = borderTrain_model.predict(train_dataB.iloc[ :, 1: ])

# %%
train_dataB.loc[train_predB > optimal_thresholdB, "train_pred"] = 1

# %%
confusion_matrxTrainB = pd.crosstab(train_dataB.train_pred, train_dataB['Class'])
confusion_matrxTrainB
# Out:
# Class            0       1
# train_pred
# 0.0         198488     234
# 1.0            427  198892

# %%
accuracy_trainB = (198488 + 198892)/(198488+198892+234+427)
print(accuracy_trainB)
# Out:
# 0.998339367050128

# %% [markdown]
# UNDER SamplingMODEL

# %%
under_model = smodel.logit('Class ~ Comp0 + Comp1 + Comp2 + Comp3 + Comp4 + Comp5 + Comp6 + Comp7 + Comp8', data = finalUnder).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.023755
#          Iterations 15

# %%
under_pred = under_model.predict(finalUnder.iloc[:,0:])

# %%
fprU, tprU, thresholdsU = roc_curve(finalUnder.Class, under_pred)

# %%
optimal_idxU = np.argmax(tprU - fprU)

# %%
optimal_thresholdU = thresholdsU[optimal_idxU]
optimal_thresholdU
# Out:
# 0.3924669713226395

# %%
roc_aucU = auc(fprU, tprU)
print("Area under the ROC curve : %f" % roc_aucU)
# Out:
# Area under the ROC curve : 0.999496

# %%
finalUnder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1476 entries, 0 to 1475
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Class   1476 non-null   int64
#  1   Comp0   1476 non-null   float64
#  2   Comp1   1476 non-null   float64
#  3   Comp2   1476 non-null   float64
#  4   Comp3   1476 non-null   float64
#  5   Comp4   1476 non-null   float64
#  6   Comp5   1476 non-null   float64
#  7   Comp6   1476 non-null   float64
#  8   Comp7   1476 non-null   float64
#  9   Comp8   1476 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 115.4 KB

# %%
finalUnder["pred"] = np.zeros(1476)

# %%
finalUnder.loc[under_pred > optimal_thresholdU, "pred"] = 1

# %%
finalUnder['pred'].value_counts()
# Out:
# 0.0    982
# 1.0    494
# Name: pred, dtype: int64

# %%
classificationUnder = classification_report(finalUnder["pred"], finalUnder["Class"])
print(classificationUnder)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99       982
#          1.0       0.99      0.99      0.99       494
#
#     accuracy                           0.99      1476
#    macro avg       0.99      0.99      0.99      1476
# weighted avg       0.99      0.99      0.99      1476

# %%
train_dataU, test_dataU = train_test_split(finalUnder, test_size = 0.3) # 30% test data

# %%
underTrain_model = smodel.logit('Class ~ Comp0 + Comp1 + Comp2 + Comp3 + Comp4 + Comp5 + Comp6 + Comp7 + Comp8', data = train_dataU).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.026690
#          Iterations 15

# %%
underTrain_model.summary2() # for AIC
underTrain_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                 1033
# Model:                          Logit   Df Residuals:                     1023
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 16 Aug 2022   Pseudo R-squ.:                  0.9578
# Time:                        21:56:00   Log-Likelihood:                -27.571
# converged:                       True   LL-Null:                       -653.04
# Covariance Type:            nonrobust   LLR p-value:                1.216e-263
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.7364      4.789      5.165      0.000      15.350      34.122
# Comp0         19.6145      3.744      5.239      0.000      12.277      26.952
# Comp1         -4.2150      0.999     -4.218      0.000      -6.174      -2.256
# Comp2          2.0474      0.711      2.880      0.004       0.654       3.441
# Comp3         -1.9229      0.507     -3.791      0.000      -2.917      -0.929
# Comp4          0.0645      0.266      0.243      0.808      -0.456       0.585
# Comp5         -1.1438      0.473     -2.419      0.016      -2.070      -0.217
# Comp6          1.9548      0.500      3.913      0.000       0.976       2.934
# Comp7          2.4321      0.634      3.835      0.000       1.189       3.675
# Comp8          2.0183      0.508      3.975      0.000       1.023       3.013
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.76 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
test_pred = logit_model.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 test_pred = logit_model.predict(test_data)
#
# NameError: name 'logit_model' is not defined

# %%
finalBorder.head()
finalBorder2 = finalBorder.copy()

# %%
finalBorder2.drop(columns='pred',inplace=True)

# %%
trainData, testData = train_test_split(finalBorder2,test_size=.3)

# %%
trainData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398041 entries, 162322 to 532243
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Class   398041 non-null  int64
#  1   Comp0   398041 non-null  float64
#  2   Comp1   398041 non-null  float64
#  3   Comp2   398041 non-null  float64
#  4   Comp3   398041 non-null  float64
#  5   Comp4   398041 non-null  float64
#  6   Comp5   398041 non-null  float64
#  7   Comp6   398041 non-null  float64
# dtypes: float64(7), int64(1)
# memory usage: 27.3 MB

# %%
testData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170589 entries, 430135 to 523996
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Class   170589 non-null  int64
#  1   Comp0   170589 non-null  float64
#  2   Comp1   170589 non-null  float64
#  3   Comp2   170589 non-null  float64
#  4   Comp3   170589 non-null  float64
#  5   Comp4   170589 non-null  float64
#  6   Comp5   170589 non-null  float64
#  7   Comp6   170589 non-null  float64
# dtypes: float64(7), int64(1)
# memory usage: 11.7 MB

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(trainData)

# trainData = scaler.transform(trainData)
# testData = scaler.transform(testData)

# %%
traintarget = trainData.Class 
testtarget = testData.Class

# %%
trainData.drop(columns='Class',inplace=True)
testData.drop(columns='Class',inplace=True)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(trainData, traintarget)
# Out:
# KNeighborsClassifier()

# %%
testpred = classifier.predict(testData)

# %%
testpred
# Out:
# array([1, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(testtarget, testpred))
print(classification_report(testtarget, testpred))
# Out:
# [[85377    18]
#  [   26 85168]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85395
#            1       1.00      1.00      1.00     85194
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589

# %%
error = []

# Calculating error for K values between 1 and 40
for i in range(1, 40):
    print(i)
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(trainData, traintarget)
    pred_i = knn.predict(testData)
    error.append(np.mean(pred_i != testpred))

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
# Out:
# Text(0, 0.5, 'Mean Error')

# %%
# use 5 or 6 for nearest neighbor
